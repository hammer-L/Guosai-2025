# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import time

import matplotlib.pyplot as plt
# 设置中文字体支持
plt.rcParams['font.sans-serif'] = ['SimHei']  # 设置支持中文的字体，优先使用SimHei
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题
sns.set_theme(style="white", font_scale=1.2)

df = pd.read_excel('filtered-ref-converted.xlsx')

bins = [27, 31.5, 33.5, 38]
labels = ['low', 'mid', 'high']

df['bmi_group'] = pd.cut(df['孕妇BMI'], bins=bins, labels=labels, right=True)

# 查看每个区间的数量
print(df['bmi_group'].value_counts())

# 获取各分组的数据
df_low = df[df['bmi_group'] == 'low'].copy()
df_mid = df[df['bmi_group'] == 'mid'].copy()
df_high = df[df['bmi_group'] == 'high'].copy()
df_low['孕妇BMI'].head()
# Out:
# bmi_group
# low     409
# mid     227
# high    214
# Name: count, dtype: int64
# 0    28.125000
# 1    28.515625
# 2    28.906250
# 7    30.742188
# 8    30.742188
# Name: 孕妇BMI, dtype: float64

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from copulas.multivariate import GaussianMultivariate
from mpl_toolkits.mplot3d import Axes3D
# 加载数据
df = pd.read_excel('filtered-ref-converted.xlsx')

# BMI分组
bins = [27.5, 31.25, 33.5, 38]
labels = ['low', 'mid', 'high']
df['bmi_group'] = pd.cut(df['孕妇BMI'], bins=bins, labels=labels, right=True)

# 查看每个区间的数量
print(df['bmi_group'].value_counts())

# 获取各分组的数据
df_low = df[df['bmi_group'] == 'low'].copy()
df_mid = df[df['bmi_group'] == 'mid'].copy()
df_high = df[df['bmi_group'] == 'high'].copy()

weeks = np.arange(10, 25.5, 0.5)

# 定义Copula优化函数
def fit_copula_and_optimize(df_group, lam=0.1):
    data = df_group[['孕妇BMI', '孕周', 'Y染色体浓度']].dropna()
    if len(data) < 30:
        print("数据不足，跳过")
        return None, None, None, None
    
    # Copula 拟合
    copula = GaussianMultivariate()
    copula.fit(data)
    
    # 从拟合的 copula 里采样大规模数据
    samples = copula.sample(5000)
    
    weeks = np.arange(10, 25.5, 0.5)
    U_values = []
    probabilities = []
    
    for t in weeks:
        bmi_mean = data['孕妇BMI'].mean()
        # 取条件子集 (孕周接近 t, BMI 接近均值)
        cond = samples[
            (np.abs(samples['孕周'] - t) <= 0.3) &
            (np.abs(samples['孕妇BMI'] - bmi_mean) <= 1.0)
        ]
        
        if len(cond) == 0:
            prob = 0
        else:
            prob = np.mean(cond['Y染色体浓度'] >= 0.04)
        
        probabilities.append(prob)
        
        # 风险成本
        if t <= 12:
            C = np.exp(-12 + t)
        elif 12 < t <= 27:
            C = 1 + 1/14*t
        else:
            C = 2 * np.exp (t - 28)
        
        U = prob - lam * C
        U_values.append(U)
    
    best_idx = int(np.argmax(U_values))
    best_t = weeks[best_idx]
    
    return best_t, U_values, probabilities, samples

# 运行优化函数
best_low, U_low, prob_low, samples_low = fit_copula_and_optimize(df_low, lam=0.02)
best_mid, U_mid, prob_mid, samples_mid = fit_copula_and_optimize(df_mid, lam=0.02)
best_high, U_high, prob_high, samples_high = fit_copula_and_optimize(df_high, lam=0.02)

# 打印结果
print("低BMI最佳时点:", best_low)
print("中BMI最佳时点:", best_mid)
print("高BMI最佳时点:", best_high)
# Out:
# bmi_group
# low     390
# mid     244
# high    214
# Name: count, dtype: int64
# C:\Users\锤子\AppData\Roaming\Python\Python38\site-packages\scipy\stats\_continuous_distns.py:709: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\锤子\AppData\Roaming\Python\Python38\site-packages\scipy\stats\_continuous_distns.py:5574: RuntimeWarning: divide by zero encountered in divide
#   return c**2 / (c**2 - n**2)
# C:\Users\锤子\AppData\Roaming\Python\Python38\site-packages\scipy\stats\_distn_infrastructure.py:2789: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\锤子\AppData\Roaming\Python\Python38\site-packages\scipy\stats\_continuous_distns.py:5574: RuntimeWarning: divide by zero encountered in divide
#   return c**2 / (c**2 - n**2)
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import make_interp_spline

# -------------------------
# Y浓度 vs 孕周 + 概率曲线（合并版）
# -------------------------
fig, ax = plt.subplots(figsize=(10, 7))

# 设置可视化样式
plt.style.use('default')
sns.set_palette("Set2")
plt.rcParams['font.size'] = 10

# Low BMI
if prob_low is not None:
    ax.scatter(df_low['孕周'], df_low['Y染色体浓度'], 
               alpha=0.5, s=40, color="blue", label="Observed - Low BMI")
    ax.plot(weeks, prob_low, color='blue', linewidth=2,
            label="Prob Curve - Low BMI")

# Mid BMI
if prob_mid is not None:
    ax.scatter(df_mid['孕周'], df_mid['Y染色体浓度'], 
               alpha=0.5, s=40, color="green", label="Observed - Mid BMI")
    ax.plot(weeks, prob_mid, color='green', linewidth=2,
            label="Prob Curve - Mid BMI")

# High BMI
if prob_high is not None:
    ax.scatter(df_high['孕周'], df_high['Y染色体浓度'], 
               alpha=0.5, s=40, color="red", label="Observed - High BMI")
    ax.plot(weeks, prob_high, color='red', linewidth=2,
            label="Prob Curve - High BMI")

# 阈值线
ax.axhline(0.04, color='gray', linestyle='--', alpha=0.7, label="Threshold 0.04")

# 设置标签和标题
ax.set_xlabel("Gestational Week")
ax.set_ylabel("Y-chromosome concentration")
ax.set_title("Y concentration vs Gestational Week with Probability Curves (by BMI group)")
ax.legend()
ax.grid(alpha=0.3)

plt.show()
    
    
    

# 创建综合可视化
fig = plt.figure(figsize=(16, 12))
gs = GridSpec(3, 2, figure=fig)

# 孕周范围
weeks = np.arange(10, 25.5, 0.5)

# 1. 效用函数曲线对比
"""
ax1 = fig.add_subplot(gs[0, :])
if U_low is not None:
    ax1.plot(weeks, U_low, label=f'Low BMI (Optimal: {best_low:.1f} weeks)', linewidth=2.5)
if U_mid is not None:
    ax1.plot(weeks, U_mid, label=f'Mid BMI (Optimal: {best_mid:.1f} weeks)', linewidth=2.5)
if U_high is not None:
    ax1.plot(weeks, U_high, label=f'High BMI (Optimal: {best_high:.1f} weeks)', linewidth=2.5)
    
    
# 标记最佳时点
if best_low is not None:
    ax1.axvline(x=best_low, color='blue', linestyle='--', alpha=0.7)
if best_mid is not None:
    ax1.axvline(x=best_mid, color='green', linestyle='--', alpha=0.7)
if best_high is not None:
    ax1.axvline(x=best_high, color='red', linestyle='--', alpha=0.7)
"""

ax1 = fig.add_subplot(gs[0, :])
weeks_dense = np.linspace(weeks.min(), weeks.max(), 300)

if U_low is not None:
    # 使用三次样条插值进行平滑
    spl_low = make_interp_spline(weeks, U_low, k=3)
    U_low_smooth = spl_low(weeks_dense)
    ax1.plot(weeks_dense, U_low_smooth, label=f'Low BMI (Optimal: {best_low:.1f} weeks)', 
             linewidth=2.5, color='#2E86AB', alpha=0.9)
    # 标记最优解点
    ax1.scatter(best_low, spl_low(best_low), color='#2E86AB', s=80, zorder=5, 
               edgecolors='white', linewidth=1.5)

if U_mid is not None:
    spl_mid = make_interp_spline(weeks, U_mid, k=3)
    U_mid_smooth = spl_mid(weeks_dense)
    ax1.plot(weeks_dense, U_mid_smooth, label=f'Mid BMI (Optimal: {best_mid:.1f} weeks)', 
             linewidth=2.5, color='#A23B72', alpha=0.9)
    ax1.scatter(best_mid, spl_mid(best_mid), color='#A23B72', s=80, zorder=5,
               edgecolors='white', linewidth=1.5)

if U_high is not None:
    spl_high = make_interp_spline(weeks, U_high, k=3)
    U_high_smooth = spl_high(weeks_dense)
    ax1.plot(weeks_dense, U_high_smooth, label=f'High BMI (Optimal: {best_high:.1f} weeks)', 
             linewidth=2.5, color='#F18F01', alpha=0.9)
    ax1.scatter(best_high, spl_high(best_high), color='#F18F01', s=80, zorder=5,
               edgecolors='white', linewidth=1.5)


# 标记风险区域
ax1.axvspan(10, 12, alpha=0.1, color='green', label='Low Risk (≤12 weeks)')
ax1.axvspan(12, 27, alpha=0.1, color='yellow', label='Medium Risk (13-27 weeks)')
ax1.axvspan(27, 25.5, alpha=0.1, color='red', label='High Risk (≥28 weeks)')

ax1.set_xlabel('Gestational Week')
ax1.set_ylabel('Utility Function U = Accuracy - λ·Risk')
ax1.set_title('Utility Function by BMI Group and Gestational Week')
ax1.legend()
ax1.grid(True, alpha=0.3)



# 5. 准确率曲线
ax5 = fig.add_subplot(gs[2, 1])
if prob_low is not None:
    ax5.plot(weeks, prob_low, label='Low BMI', linewidth=2.5, color='blue')
if prob_mid is not None:
    ax5.plot(weeks, prob_mid, label='Mid BMI', linewidth=2.5, color='green')
if prob_high is not None:
    ax5.plot(weeks, prob_high, label='High BMI', linewidth=2.5, color='red')

ax5.axhline(y=0.95, color='black', linestyle='--', linewidth=2, label='95% Accuracy Target')
ax5.set_xlabel('Gestational Week')
ax5.set_ylabel('Accuracy Probability')
ax5.set_title('Estimated Accuracy by Gestational Week')
ax5.legend()
ax5.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# 输出结果摘要
print("=" * 60)
print("NIPT TESTING OPTIMIZATION RESULTS")
print("=" * 60)
print(f"{'BMI Group':<12} {'Optimal Week':<15} {'Risk Level':<12}")
print("-" * 60)

for group, week in zip(bmi_groups, best_weeks):
    if week is not None:
        risk = "Low" if week <= 12 else "Medium" if week <= 27 else "High"
        print(f"{group:<12} {week:<15.1f} {risk:<12}")

print("-" * 60)
print("RECOMMENDATIONS:")
print("1. Lower BMI groups can test earlier with good accuracy")
print("2. Higher BMI groups may need to test later for reliable results")
print("3. Consider risk-benefit trade-off when choosing testing time")
print("=" * 60)
# Out:
# ...
# NIPT TESTING OPTIMIZATION RESULTS
# ...
# BMI Group    Optimal Week    Risk Level
# ------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 149
#     146 print(f"{'BMI Group':<12} {'Optimal Week':<15} {'Risk Level':<12}")
#     147 print("-" * 60)
# --> 149 for group, week in zip(bmi_groups, best_weeks):
#     150     if week is not None:
#     151         risk = "Low" if week <= 12 else "Medium" if week <= 27 else "High"
#
# NameError: name 'bmi_groups' is not defined

# %%
import pandas as pd
import numpy as np
from copulas.multivariate import GaussianMultivariate

def fit_copula_and_optimize(df_group, lam=0.1):
    data = df_group[['孕妇BMI', '孕周', 'Y染色体浓度']].dropna()
    if len(data) < 30:
        print("数据不足，跳过")
        return None, None

    # Copula 拟合
    copula = GaussianMultivariate()
    copula.fit(data)

    # 从拟合的 copula 里采样大规模数据
    samples = copula.sample(10000)

    weeks = np.arange(10, 25.5, 0.5)
    U_values = []

    for t in weeks:
        bmi_mean = data['孕妇BMI'].mean()

        # 取条件子集 (孕周接近 t, BMI 接近均值)
        cond = samples[
            (np.abs(samples['孕周'] - t) <= 0.3) &
            (np.abs(samples['孕妇BMI'] - bmi_mean) <= 1.0)
        ]

        if len(cond) == 0:
            prob = 0
        else:
            prob = np.mean(cond['Y染色体浓度'] >= 0.04)

        # 风险成本
        if t <= 12:
            C = 1
        elif 13 <= t <= 27:
            C = 2
        else:
            C = 3

        U = prob - lam * C
        U_values.append(U)

    best_idx = int(np.argmax(U_values))
    best_t = weeks[best_idx]
    return best_t, U_values

best_low, U_low = fit_copula_and_optimize(df_low, lam=0.151)
best_mid, U_mid = fit_copula_and_optimize(df_mid, lam=0.15)
best_high, U_high = fit_copula_and_optimize(df_high, lam=0.145)

print("低BMI最佳时点:", best_low)
print("中BMI最佳时点:", best_mid)
print("高BMI最佳时点:", best_high)
